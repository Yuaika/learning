# %%
import os
import cv2 as cv

oldpath = "C:/Users/86188/Desktop/image1/"
newpath = "C:/Users/86188/Desktop/image2/"
filelist = os.listdir(oldpath) #该文件夹下所有的文件（包括文件夹）
count=1
for file in filelist:
    print(file)
for file in filelist:   #遍历所有文件
    img = cv.imread(oldpath+file)
    cv.imwrite(newpath+str(count).zfill(6)+".jpg",img)
    count+=1
# Out:
# 100_rgb.png
# 10_rgb.png
# 11_rgb.png
# 12_rgb.png
# 13_rgb.png
# 14_rgb.png
# 15_rgb.png
# 16_rgb.png
# 17_rgb.png
# 18_rgb.png
# 19_rgb.png
# 20_rgb.png
# 21_rgb.png
# 22_rgb.png
# 23_rgb.png
# 24_rgb.png
# 25_rgb.png
# 26_rgb.png
# 27_rgb.png
# 28_rgb.png
# 29_rgb.png
# 2_rgb.png
# 30_rgb.png
# 31_rgb.png
# 33_rgb.png
# 34_rgb.png
# 35_rgb.png
# 36_rgb.png
# 37_rgb.png
# 38_rgb.png
# 39_rgb.png
# 3_rgb.png
# 40_rgb.png
# 41_rgb.png
# 42_rgb.png
# 43_rgb.png
# 44_rgb.png
# 45_rgb.png
# 46_rgb.png
# 47_rgb.png
# 48_rgb.png
# 49_rgb.png
# 4_rgb.png
# 50_rgb.png
# 51_rgb.png
# 52_rgb.png
# 53_rgb.png
# 54_rgb.png
# 55_rgb.png
# 56_rgb.png
# 57_rgb.png
# 58_rgb.png
# 59_rgb.png
# 5_rgb.png
# 60_rgb.png
# 61_rgb.png
# 62_rgb.png
# 63_rgb.png
# 64_rgb.png
# 65_rgb.png
# 66_rgb.png
# 67_rgb.png
# 68_rgb.png
# 69_rgb.png
# 6_rgb.png
# 70_rgb.png
# 71_rgb.png
# 72_rgb.png
# 73_rgb.png
# 75_rgb.png
# 76_rgb.png
# 77_rgb.png
# 78_rgb.png
# 79_rgb.png
# 7_rgb.png
# 80_rgb.png
# 81_rgb.png
# ...

# %%
import os
path = "C:/Users/86188/Desktop/annotation1/"
newpath = "C:/Users/86188/Desktop/annotation2/"
filelist = os.listdir(path) #该文件夹下所有的文件（包括文件夹）
count=1
for file in filelist:
    print(file)
for file in filelist:   #遍历所有文件
    Olddir=os.path.join(path,file)   #原来的文件路径
    if os.path.isdir(Olddir):   #如果是文件夹则跳过
        continue
    filename=os.path.splitext(file)[0]   #文件名
    filetype=os.path.splitext(file)[1]   #文件扩展名
    Newdir=os.path.join(newpath,str(count).zfill(6)+filetype)  #用字符串函数zfill 以0补全所需位数
    os.rename(Olddir,Newdir)#重命名
    count+=1
# Out:
# 100_rgb.xml
# 10_rgb.xml
# 11_rgb.xml
# 12_rgb.xml
# 13_rgb.xml
# 14_rgb.xml
# 15_rgb.xml
# 16_rgb.xml
# 17_rgb.xml
# 18_rgb.xml
# 19_rgb.xml
# 20_rgb.xml
# 21_rgb.xml
# 22_rgb.xml
# 23_rgb.xml
# 24_rgb.xml
# 25_rgb.xml
# 26_rgb.xml
# 27_rgb.xml
# 28_rgb.xml
# 29_rgb.xml
# 2_rgb.xml
# 30_rgb.xml
# 31_rgb.xml
# 33_rgb.xml
# 34_rgb.xml
# 35_rgb.xml
# 36_rgb.xml
# 37_rgb.xml
# 38_rgb.xml
# 39_rgb.xml
# 3_rgb.xml
# 40_rgb.xml
# 41_rgb.xml
# 42_rgb.xml
# 43_rgb.xml
# 44_rgb.xml
# 45_rgb.xml
# 46_rgb.xml
# 47_rgb.xml
# 48_rgb.xml
# 49_rgb.xml
# 4_rgb.xml
# 50_rgb.xml
# 51_rgb.xml
# 52_rgb.xml
# 53_rgb.xml
# 54_rgb.xml
# 55_rgb.xml
# 56_rgb.xml
# 57_rgb.xml
# 58_rgb.xml
# 59_rgb.xml
# 5_rgb.xml
# 60_rgb.xml
# 61_rgb.xml
# 62_rgb.xml
# 63_rgb.xml
# 64_rgb.xml
# 65_rgb.xml
# 66_rgb.xml
# 67_rgb.xml
# 68_rgb.xml
# 69_rgb.xml
# 6_rgb.xml
# 70_rgb.xml
# 71_rgb.xml
# 72_rgb.xml
# 73_rgb.xml
# 75_rgb.xml
# 76_rgb.xml
# 77_rgb.xml
# 78_rgb.xml
# 79_rgb.xml
# 7_rgb.xml
# 80_rgb.xml
# 81_rgb.xml
# ...
